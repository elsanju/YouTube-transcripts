# %%
import pandas as pd, matplotlib.pyplot as plt

# %%
videoID = "ml6cT4AZdqI" #https://www.youtube.com/watch?v=ml6cT4AZdqI

# %%
#Get subtitles & count the words
def getData(videoID):
    from youtube_transcript_api import YouTubeTranscriptApi
    data = YouTubeTranscriptApi.get_transcript(videoID, languages = ['en'])
    df = pd.DataFrame(data)
    compList = list(df['text'].str.split(" "))
    flatList = [item for sublist in compList for item in sublist]
    wordsDF = pd.DataFrame(flatList, columns = ['words'])
    count = wordsDF.words.value_counts().to_frame()
    return count

# %%
#Exclude not important words
def filterData(df):
    filt = "and that to those of as it in the one seconds switch you a "
    filt += "we go right and the seconds here you to it a left up"
    filtList = filt.split()
    ret = df[~df.index.isin(filtList)]
    return ret

# %%
#Making the chart
def graf(df, n=1):
    top = dataF.head(n)
    plt.style.use('dark_background')
    fig, ax = plt.subplots(figsize = (15,5))
    ax.bar(top.index, top.words, color = 'tab:red')
    plt.xticks()
    return plt

# %%
data = getData(videoID)
dataF = filterData(data)
bar = graf(dataF, 3)
bar.show()
dataDict = {}

# %% [markdown]
# ### All the words the video is mentioning

# %%
for idx, row in data.head(200).iterrows():
     dataDict[idx] = row.words
print(dataDict)
# Out:
# {'we': 108, 'go': 107, 'right': 89, 'and': 86, 'the': 82, 'seconds': 82, 'here': 78, 'you': 70, 'to': 70, 'it': 62, 'a': 61, 'left': 52, 'up': 50, 'good': 49, 'nice': 49, 'guys': 46, 'your': 45, 'is': 39, 'gonna': 36, 'so': 34, 'in': 34, 'all': 32, 'one': 32, "we're": 31, "let's": 30, 'this': 30, 'with': 28, 'three': 26, 'I': 26, 'Reese': 26, 'two': 24, 'that': 24, 'again': 24, 'into': 24, 'down': 24, 'done': 23, 'back': 23, 'our': 23, 'through': 23, 'on': 22, 'five': 22, 'got': 22, 'get': 21, 'out': 21, 'side': 20, 'move': 20, 'of': 19, 'high': 19, 'now': 19, 'do': 19, 'core': 18, 'come': 18, 'for': 17, 'deep': 17, 'ten': 17, 'perfect': 16, "I'm": 16, 'knees': 15, 'over': 15, 'find': 15, 'those': 15, 'have': 14, 'want': 14, 'arms': 14, 'there': 14, "it's": 14, 'feet': 14, 'doing': 13, 'okay': 13, 'second': 13, "don't": 13, 'just': 13, 'ready': 13, 'stretch': 13, "you're": 13, 'almost': 12, 'are': 12, 'modification': 12, 'before': 11, 'more': 10, 'shoulders': 10, 'moving': 10, 'jumps': 10, 'star': 10, 'smile': 10, 'keep': 10, 'chest': 10, 'if': 10, 'breathe': 10, 'toe': 10, 'forget': 9, 'opposite': 9, 'hips': 9, 'squeeze': 9, 'be': 9, 'engage': 9, 'me': 9, 'halfway': 9, 'circuit': 9, 'little': 9, 'but': 9, 'pace': 9, 'not': 8, 'take': 8, 'bit': 8, 'straight': 8, 'finish': 8, 'looks': 8, 'round': 8, 'using': 8, 'four': 8, 'arm': 8, 'squats': 8, 'my': 8, 'first': 8, 'really': 8, 'coming': 8, 'workout': 8, 'easy': 8, 'at': 7, 'then': 7, 'outside': 7, 'standing': 7, '20': 7, 'remember': 7, 'power': 7, 'final': 7, 'feeling': 7, 'can': 7, "we've": 7, 'going': 6, 'because': 6, 'about': 6, 'buddy': 6, 'hey': 6, 'hands': 6, 'regular': 6, 'clock': 6, 'by': 6, 'foot': 6, 'lunges': 6, 'some': 6, 'alright': 6, 'breathing': 6, 'his': 6, 'top': 6, '15': 6, "that's": 6, 'next': 6, 'last': 6, "he's": 6, 'start': 6, '30': 6, 'feel': 6, '10': 6, 'breath': 6, 'know': 6, 'jumping': 6, 'thirty': 5, 'stay': 5, 'well': 5, 'give': 5, 'which': 5, 'strong': 5, 'body': 5, 'hold': 5, 'engaged': 5, 'low': 5, 'how': 5, 'mat': 5, 'swing': 4, 'rest': 4, 'like': 4, 'starting': 4, 'ok': 4, 'big': 4, 'jump': 4, 'tight': 4, 'bending': 4, "you've": 4, 'pull': 4, 'hinging': 4, 'as': 4, 'mountain': 4, 'time': 4, 'tricep': 4, 'stop': 4, 'fast': 4, 'much': 4, 'notice': 4, 'London': 4, 'cool': 4, 'driving': 4, 'sure': 4, 'slow': 4, 'form': 4, 'elbows': 4, 'what': 4, 'looking': 4, 'water': 4}
